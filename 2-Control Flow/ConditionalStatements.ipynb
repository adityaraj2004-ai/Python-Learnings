# %%
# if statement
age = 20
if age > 18:
    print("You are Allowed to vote in elections")
# Out:
# You are Allowed to vote in elections

# %%
age >= 18
# Out:
# True

# %%
# else
# The else statement executes a block of code if the condition in the if statement is False.

age = 16

if age>=18:
    print("You are eligible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
# elif 
# allows you to check for multiple statements it stands for "else if"

age = 17

if age < 13:
    print("You are a child")
elif age < 18:
    print("You are a teenager")
else:
    print("Hey! You are an adult")
# Out:
# You are a teenager

# %%
# Nested Conditionals
# one or more if elif conditionals inside each other 
# given number tell even, odd, negative 

num = int(input("Enter the number: "))
if num >=0:
    print("The number is Positive ") 
    if num % 2 == 0:
        print("THe number is also Even ")
    else:
        print("The number is also Odd")        
else:
    print("The number is negative")
# Out:
# The number is Positive
# THe number is also Even

# %%
# Practical Example
# Determine whether a year is leap year.

year = int(input("Enter the Year"))

if year < 0:
    print("year cannot be negative")
elif year>=0 & year %4 ==0:
    print("It is a Leap Year")
else:
    print("It is not a Leap Year")
# Out:
# It is a Leap Year

# %%
year = int(input("Enter the year"))

if year%4 == 0:
    if year%100 == 0:
        if year % 400 ==0 :
            print(year, ": is a Leap Year")
        else:
            print(year, ": is not a Leap Year")
    else:
            print(year, ": is a Leap Year") 
else:
            print(year, ": is not a Leap Year")
# Out:
# 1900 : is not a Leap Year

# %%
## SImple Calculator 

num1 = float(input("Enter the Number:"))
print("The First Number : ", num1)
num2 = float(input("Enter the Number:"))
print("The Second Number : ", num2)

operation = input("Enter the Operations (+ - / * :) ")
print("The Operation to be performed: ",operation)

if operation  == '+':
    result = num1+num2
elif operation == '-':
    result = num1-num2
elif operation == '*':
    result = num1*num2
elif operation == '/':
    if num2 != 0:
        result = num1/num2
    else:
        print("Division Error")
    
print("The result is :", result)
# Out:
# The First Number :  3.0
# The First Number :  5.0
# The Operation to be performed:  *
# The result is : 15.0
