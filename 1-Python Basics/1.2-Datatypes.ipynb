# %%
# Integers Examples
age = 35
type(age)
# Out:
# int

# %%
# Flaoting Point Example
height = 6.1
print(height)
type(height)
# Out:
# 6.1
# float

# %%
# String Data Example
name = "Aditya"
print(name)
type(name)
# Out:
# Aditya
# str

# %%
# Boolean Datatype
type(True)
is_True = bool()
type(is_True)
# Out:
# False

# %%
# By Default bool() has false value
bool()
# Out:
# False

# %%
a = 10
b=10
a == b #true
# Out:
# True

# %%
# Common Errors 

result = "Hello" + 5 # TypeError Concatenating String with Integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Common Errors
#       2
# ----> 3 result = "Hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "Hello " + "5" # can also typecast 5 as str => result = "Hello " + str(5)
print(result)
# Out:
# Hello 5
